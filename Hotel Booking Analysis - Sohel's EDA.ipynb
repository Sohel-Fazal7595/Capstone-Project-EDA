# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - SK Md Sohel Fajal **

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. We will be doing Exploratory Data Analysis on the given dataset to gain insights into the world of Hotel Booking.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Welcome to the world of hotel booking.
# In the world of hotels bookings are volatile depending of some factors.
# The duration of stay is also affected by certain other factors.
# Through the given dataset we have to find out such factors which affect the world of hotel booking.
# As a result the required action to be taken to boost sales may become insightful by analysis such a dataset.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Gain insights on the factors which aid in hotel booking and increase the duration of stay to get positive business revenue.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/Hotel Bookings.csv")
#read_csv function reads a csv file and converts it into a dataframe

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
#head function show the specified number of rows from the start of the dataframe, when arguments are empty it shows first 5

# %%
df.tail()
#to see the last 5 rows of the dataframe

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
#shape attributes show the number of rows and columns in the dataframe

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
#info method give the information about the type of the columns and the number of non null values

# %%
df.describe(include = "all")
#describe method describes the values present in the columns of the dataframe

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()

# %%
df.duplicated().value_counts()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_in_df = df.isna().sum().sort_values(ascending = False)[:10]
missing_in_df = missing_in_df.reset_index().rename(columns = {"index" : "column", 0 : "null values"})
missing_in_df

# %%
# Visualizing the missing values
sns.barplot(data = missing_in_df, x = "column", y = "null values")
plt.xticks(rotation = 90)
plt.show()

# %%
df["company"].fillna(0, inplace = True)
#Fills 0 in place of null in the company column

# %%
df["adults"].fillna(0, inplace = True)

# %%
df["children"].fillna(0, inplace = True)

# %%
df["agent"].fillna(0, inplace = True)

# %%
df["country"].fillna("others", inplace = True)

# %%
df.isna().sum()

# %%
duplicate = df.duplicated().value_counts()
duplicate

# %%
color = ['blue', 'red']
plt.bar(x = duplicate.index, height = duplicate, color = color)
#barplot function of matplotlib
plt.xticks([0, 1])
plt.xlabel("Duplicate")
plt.ylabel("Count")
#Barplot shows that about 25000 records are duplicate

# %%
df.drop_duplicates(keep = False, inplace = True)
#dropping duplicates from the dataset

# %%
df.duplicated().value_counts()
#checking duplicated true/false value counts

# %%
df.shape
#showing the shape of the present dataframe

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# At first the dataset had about 119390 rows but after replacing null values with 0 and removing duplicated rows it has 79225 rows.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
#attribute which holds the column names of a dataset

# %% [markdown]
# # Dataset Describe
#
# hotel = Resort or City Hotel
#
# is_canceled = If the booking was cancelled (1) else (0)
#
# lead_time = Number of days that elapsed between the entering date of the booking into the PMS and arrival date
#
# arrival_date_year = Year of arrival date
#
# arrival_date_month = Month of arrival date
#
# arrival_date_week_number = Week number for arrival date
#
# arrival_date_day_of_month = Day of month for arrival date
#
# stays_in_weekend_nights = Number of weekend nights the guest booked the hotel for
#
# stays_in_week_nights = Number of week nights the guest booked the hotel for
#
# adults = Number of adults
#
# children = Number of children
#
# babies = Number of babies
#
# meal = Kind of meal opted for
#
# country = country code
#
# market_segment = which segment the customer belongs to
#
# distribution_channel = how the guest booked the hotel (corporate booking / direct / TA / TO)
#
# is_repeated_guest = Guest coming for first time or not
#
# previous_cancellations = If there was cancellation before
#
# previous_bookings_not_canceled = Number of previous booking which were not cancelled
#
# reserved_room_type = type of room reserved
#
# assigned_room_type = type of room assigned
#
# booking_changes = count of changes made to the booking
#
# deposit_type = Deposit type
#
# agent = Booked through agent
#
# days_in_waiting_list = Number of days in waiting list
#
# customer_type = Type of customer
#
# required_car_parking_spaces = If parking space required or not
#
# total_of_special_requests = Number of special requests made
#
# reservation_status = Status of reservation
#
# reservation_status_date = Date of status of reservation

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df["hotel"].unique()

# %%
df.columns

# %%
df["is_canceled"].unique()

# %%
df["lead_time"].unique()

# %%
df["arrival_date_year"].unique()

# %%
df["arrival_date_month"].unique()

# %%
df["arrival_date_week_number"].unique()

# %%
df["arrival_date_day_of_month"].unique()

# %%
df["stays_in_weekend_nights"].unique()

# %%
df["stays_in_week_nights"].unique()

# %%
df["adults"].unique()

# %%
df["children"].unique()

# %%
df["babies"].unique()

# %%
df["meal"].unique()

# %%
df["country"].unique()

# %%
df["market_segment"].unique()

# %%
df["distribution_channel"].unique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df["reservation_status_date"] = pd.to_datetime(df["reservation_status_date"], format = "%Y-%m-%d")
#to_datetime function converts the values of a column from string values to datetime object

# %%
df.info()
#info function shows the columns in a dataset, their datatype and non null count of the values in that column

# %%
df["total_people"] = df["adults"] + df["children"] + df["babies"]
#adding adults column, children column and babies column values to create new column called total_people

# %%
df["total_stay"] = df["stays_in_weekend_nights"] + df["stays_in_week_nights"]
#adding two columns values to create a new column called total_stay

# %%
df.head(3)
#shows the first 3 rows of the dataset

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer - 1. Created new column called 'total_people' by adding all the adults, chilren and babies.
# 2. Converted 'reservation_status_date' to datetime
# 3. Created new column called 'total_stay' by adding 'stays_in_week_nights' and 'stays_in_weekend_nights'.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## 1. Pie chart of type of hotel - "City hotel or Resort hotel"

# %%
df["hotel"].value_counts()
#using the value_counts function which shows the count of the values present in the column.

# %%
plt.pie(x = df["hotel"].value_counts(), labels = ["City Hotel", "Resort Hotel"], autopct = "%1.1f")
#pie function of matplotlib.pyplot to create pie chart
plt.title("Percentage of City and Resort hotels")
#setting title of the created chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ## I used this chart to see what types of hotels are there and where are their percentages.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - 60 % are city hotels and around 40 % are resort hotels.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights will help in understanding the distribution of the hotels and know what type of hotel to build next time it is planned.

# %% [markdown]
# ## 2. Number of bookings that are cancelled

# %%
cancelled = df["is_canceled"].value_counts().reset_index().rename(columns = {"index": "cancelled", "is_canceled": "count"})
cancelled
#checking the value counts of the is_cancelled column, resetting the resultant series in to a dataframe and renaming its columns

# %%
fig, ax = plt.subplots()
ax.bar(cancelled["cancelled"], cancelled["count"], color = ["green", "red"])
#bar function of matplotlib which is used to create bar graph
ax.set_title("Count of cancelled bookings")
ax.set_xticks([0, 1])
#replacing the values of the x axis
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used this chart to understand the amount of bookings that are cancelled.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - About 20000 of the hotel bookings get cancelled, as seen from the dataset.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If the rate of cancellation fluctuates from the normal which is seen from this chart additional steps may be taken to help the situation.

# %% [markdown]
# ## 3. Percentage of bookings that get cancelled

# %%
is_cancelled = df["is_canceled"].value_counts()
#using the value_counts function which shows the count of the values present in the column.
is_cancelled

# %%
fig, ax = plt.subplots()
ax.pie(is_cancelled, labels = is_cancelled.index, autopct = "%1.1f", colors = sns.color_palette("Set2"))
ax.set_title("Percentage of cancelled bookings")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used this chart to understand the percentage of booking that get cancelled.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - About 26.2 % bookings get cancelled.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights help to understand the amount of cancellation that a hotel owner can expect when operating a hotel business.

# %% [markdown]
# ## 4. Count of booking changes that are made

# %%
booking_changes = df["booking_changes"].value_counts().reset_index().rename(columns = {"index": "Number of booking changes", "booking_changes": "count"})[: 10]
#checking value counts, resetting index, renaming columns and slicing in one line
booking_changes

# %%
plt.figure(figsize = (10, 6))
sns.barplot(data = booking_changes, x = "Number of booking changes", y = "count", palette = "bright").set_title("Count of number of booking changes")
#barplot function of seaborn used to create a bar graph
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used this chart to see the count of discrete numerical column called booking changes

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Most of the bookings have no changes about 10000 have 1 change and 3000 have 2 changes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights show the usual number of booking changes that the guests make. Thus the staff must at most times expect 1 or 2 changes to be made.

# %% [markdown]
# ## 5. Agent who has done the most number of bookings

# %%
agent_bookings = df.groupby(["agent"])["agent"].agg({"count"}).reset_index().rename(columns = {"count": "Most bookings"}).sort_values(by = "Most bookings", ascending = False)[:10]
#grouping by agent, and fetching count of agent column values, resetting index, renaming column names, sorting values in descending order and slicing them for the first 10 values in one line
agent_bookings

# %%
sns.barplot(data = agent_bookings, x = "agent", y = "Most bookings", palette = "inferno").set_title("Most bookings made by agents")
#barplot function of seaborn to create a bar graph
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #I used this chart to see which agent makes what number of bookings

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Agent 9 made the most bookings followed by 240 and 0.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #Specific agents may be rewarded with commission for their performance, least performing agent may be unsubscribed, depending on the insights found from this chart.

# %% [markdown]
# ## 6. Arrival distribution according to month

# %%
arrival_distribution = df["arrival_date_month"].value_counts().reset_index().rename(columns = {"index": "month", "arrival_date_month": "count"})
#doing value counts, resetting index and renaming columns
arrival_distribution

# %%
sns.barplot(data = arrival_distribution, x = "month", y = "count", palette = "deep")
#barplot function of seaborn used to create a bar graph
plt.xticks(rotation = 90)
#rotating the values of the x axis by 90 degree for better readibility0
plt.title("Bookings according to month")
#setting tile of the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see the distribution of booking according to month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Most guests arrive in the month of August, followed by July and May. Thus we can understand the seasonal trends of hotel booking. So we can say Summer season is preferred.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The gained insights can help the hotel owner understand yearly trends and how much traffic to expect according to the month.

# %% [markdown]
# ## 7. Room types that are mostly reserved

# %%
plt.figure(figsize = (8, 6))
#setting size of the figure
sns.countplot(data = df, x = "reserved_room_type", hue = "hotel", palette = "dark")
#count plot to show counts of categorical variable reserved_root_type, hue parameter is used to distribute the bar depending on city or resort hotel
plt.title("Reserved room types based on city or resort hotels")
#setting the title of the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see the distribution of bookings based on room type that is reserved.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - A, D and E are the room types most reserved among Resort and City hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The gained insights can help to determine which type of rooms and their numbers when building a city or resort hotel.

# %% [markdown]
# ## 8. Room types that are mostly assigned

# %%
plt.figure(figsize = (8, 6))
sns.countplot(data = df, x = "assigned_room_type", hue = "hotel", palette = sns.color_palette("Set1"))
plt.title("Assigned room types based on city and resort hotels")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see the distribution of bookings based on room type that is assigned.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Room types A, D, E are the most assigned among city and resort hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The gained insights can help to determine which type of rooms and their numbers when building a city or resort hotel and also to keep available which type of rooms when running a hotel.

# %% [markdown]
# ## 9. Distribution of hotel bookings arrival according to years

# %%
plt.figure(figsize = (5, 5))
#setting the figure size
sns.countplot(data = df, x = "arrival_date_year", hue = "hotel", palette = "inferno")
#countplot function of seaborn to see the count of the arrival year's occurrence
plt.title("Distribution of arrival date according to year or arrival")
#setting the title of the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see booking trends across years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Most guests arrived in the year 2016.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The insights gained from this chart can help in understanding the yearly trends of bookings , and what factors affect that trend can be tweaked.

# %% [markdown]
# ## 10. Booking distribution according to month

# %%
sns.countplot(data = df, x = "arrival_date_month", hue = "hotel", palette = "deep")
#countplot function of seaborn to create a countplot chart
plt.xticks(rotation = 90)
#rotating values of x axis for better readibility
plt.title("Bookings according to month")
#setting the title of the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see the booking distribution across months, based on city and resort hotels, in the hue.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - The half-year of October to March is the Off season for hotel business of this dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The insights gained from this chart can help to understand and act on traffic of guests based on the month of the year.

# %% [markdown]
# ## 11. Percentage of guests that rebook the same hotel

# %%
repeated = df["is_repeated_guest"].value_counts()
#value counts of is_repeated_guest column
repeated

# %%
plt.figure(figsize = (5, 5))
#setting the size of the figure
plt.pie(x = repeated, labels = [0, 1], shadow = True, autopct = "%1.1f", colors = ["orchid", "green"])
#pie function of matplotlib to show the percentage of guests that rebook the same hotel and those that dont
plt.title("% of guests that are repeated")
#setting the title of the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see the percentage of guests that rebook the same hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Only 4.2% of guests repeat the same hotel, rest are new comers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The gained insights can help in sales tactics to resell the same hotel booking. It can also help the business owner to create referral systems.

# %% [markdown]
# ## 12. Distribution of bookings made by distribution channels

# %%
distro_ch = df["distribution_channel"].value_counts().reset_index().rename(columns = {"index": "distribution_channel", "distribution_channel": "bookings_made"})
#doing value counts, resetting index and renaming columns
distro_ch

# %%
plt.figure(figsize = (5, 5))
#setting the size of the figure
sns.barplot(data = distro_ch, x = "distribution_channel", y = "bookings_made", palette = "deep")
#barplot function of seaborn to create a bar graph
plt.title("Bookings made by distribution channels")
#setting the title of the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see which distribution channel makes what share of bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - TA/TO make the most bookings followed by Direct and Corporate_distribution_channel

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The gained insights can help the business owner make appropriate reciprocation to the most effective distribution and try to rejuvenate the distribution channels with least performance.

# %%
print("0.05th quartile: ",df["lead_time"].quantile(0.05))
#Showing the 0.05th quartile
print("0.25th quartile: ",df["lead_time"].quantile(0.25))
#Showing the 0.25th quartile
print("0.75th quartile: ",df["lead_time"].quantile(0.75))
#Showing the 0.75th quartile
print("0.95th quartile: ",df["lead_time"].quantile(0.95))
#Showing the 0.95th quartile

# %% [markdown]
# ## 13. Distribution of lead time, which is the number of days elapsed between entering the arrival_date in the PMS and the arrival date.

# %%
sns.boxplot(data = df, y = "lead_time", x = "hotel")
#boxplot function of seaborn to create a boxplot chart

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see the distribution of lead time on a boxplot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Thus we can see that most guests arrive within around 100 days of booking the hotel, with a few outliers life 500 and 700 days.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The gained insights can help the business owner understand the trends in the lead time discrete numeric variable and act accordingly.

# %% [markdown]
# ##14. Distribution of bookings based on nationality

# %%
country_df = df["country"].value_counts().reset_index().rename(columns = {"index": "country", "country": "count"}).sort_values(by = "count", ascending = False)[:10]
country_df

# %%
sns.barplot(data = country_df, x = "country", y = "count", palette = sns.color_palette("Set2"))
#barplot function of seaborn to create a bar graph

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see which nationality make what number of bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Portugal, Britain, France, Spanish and German are the nationalities which make the most bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The gained insights can help the business owners make required actions like, these nationality specific dishes may be added in the menu of the hotel. Also this can help to target the booking of the guests based on their nationality.

# %% [markdown]
# ##15. Distribution of the total number of people that stay in the hotels

# %%
sns.set_style("whitegrid")
#settting style of the background grid
sns.countplot(data=df, y = "total_people", palette="colorblind")
#countplot function of seaborn to create count chart
plt.xlabel("Count")
#setting xlabel
plt.ylabel("Number of total people for stay")
#setting ylabel
plt.title("Distribution of number of people in each stay")
#setting title
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see which how many people usually stay in the hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Most bookings are for 2 people, but rooms with 3 and 4 people to accomodate should also be present.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The gained insights can help the business owners make required decisions of how to allocate rooms within their hotel, what size of room to build and the kinds of beds and furniture to keep.

# %% [markdown]
# ## 16. Distribution of total_stay - days/nights that guests stay in the hotel for

# %%
total_stay_df = df["total_stay"].value_counts().reset_index().rename(columns = {"index": "total_stay_nights", "total_stay": "count"}).sort_values(by = "count", ascending = False)[:20]
#doing value_counts, resetting index, renaming columns, sorting values and indexing
total_stay_df

# %%
sns.set_style("whitegrid")
#setting background grid style
sns.lineplot(data = total_stay_df, x = "total_stay_nights", y = "count", palette = sns.color_palette("Set3"))
#lineplot function of seaborn to create linechart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see which how many days/nights people usually stay in the hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Most bookings are for 1 to 3 nights, but some guests can be expected to stay till a week.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The gained insights can help the business owners make required decisions of how many days to keep the rooms ready for accomodation. It can help the business owners to understand the usual trend in the number of days/nights the people usually stay.

# %% [markdown]
# ##17. Distribution of total_stay on x axis and total_people on y axis

# %%
plt.figure(figsize = (7, 5))
#setting size of the figure
sns.scatterplot(data = df, x = "total_stay", y = "total_people").set_title("Total_stay vs Total_people scatter plot")
#scatterplot function of seaborn to see the presence of dots at the intersection of total_stay and total_people
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# #Used this chart to see which the trends in the number of days/nights in stay and the total_people that stay.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **Observation** - Most bookings are for 0-5 people who stay for a maximum of 30 days. Very few dots are there where total people is greater than 50 and total_stay is 70.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #The gained insights can help the business owner understand the trends in the number of people for who the rooms are books and the number of nights those people stay.

# %% [markdown]
# ##18. Distribution of meal types according to hotel

# %%
plt.figure(figsize = (9,6))
#setting a figure size for our chart
sns.countplot(x = 'meal',hue = 'hotel',data = df)
#creating a count plot using seaborn
plt.xlabel("Meal-Type",fontsize = 15)
# labeling x axis
plt.ylabel("Customer Prefer Count",fontsize = 12)
#labeling y axis
plt.title('Distribution of Meal-Type in term of customer preferation',fontsize = 15)
#setting tilte of our chart
plt.legend(title ='Hotel')
#setting legend title
plt.show()
#displaying our chart

# %% [markdown]
# **BB:** Bed and Breakfast
#
# This typically includes accommodations (bed) and breakfast. Guests receive a room for the night and breakfast the following morning. Other meals are not included.
#
# **HB:** Half Board
#
# This typically includes accommodations, breakfast, and one other meal, usually dinner. Guests receive a room for the night, breakfast, and dinner, but lunch is not included.
#
# **SC:** Self-Catering
#
# This means guests have access to cooking facilities within their accommodation and are responsible for preparing their own meals. No meals are provided by the hotel.
# **FB:** Full Board
#
# This typically includes accommodations, breakfast, lunch, and dinner. Guests receive a room for the night, as well as all three main meals of the day.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I prefer this chart because I wanted to show which meal type is more prefered by customers in both hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.I found out that both hotels have high deamnd of BB meal type.
# 2.There is no demand of FB meal type in City hotel and very less demand in Resort hotel.
# 3.As we can see there is almost no demand of SC meal type in Resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# ---
#
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes as we can see customer prefered BB meal type most so we can focused on that and have a good supply of BB meal type so the customers did not face any issue so they will come again and we can also cost cutting of FB meal type in Resort hotel so the business owner can save money.

# %% [markdown]
# ##19. Correlation heatmap

# %%
#Correlation Heatmap visualization code
plt.figure(figsize = (16,10))
sns.heatmap(df.corr(numeric_only=True),annot = True)
#heatmap function of seaborn to create heatmap chart
plt.title('Correlations of the columns',fontsize= 20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlational heatmaps was used to find potentiol relationship between variables to understand the strength of their relationship

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.required_car_parking_spaces, total_of_special_requests and total_people are positively correlated.
# 2.total_people and adr are corelated with each other.That the more the people the more the adr.
# 3.is_repeated guest and previous bookings not cancelled has strong corelation.That mean repeated guest don't cancel their bookings

# %% [markdown]
# ##20. Pairplot visualization

# %%
#Pair Plot visualization code
sns.pairplot(df)
#pairplot function of seaborn to create pairplot chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot allows us to see both distribution of single variables and relationship between two variables.We can see relationship between all the columns with each other in above chart

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I found out these insights from the above chart:
# 1. From the above pair chart we can see if cancellation increases then total stay also decreases
# 2.As the total number of people increases adr also increases Thus adr are direclty proposanal to number of people

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. City hotels are more preferred thus stack holders must maintain the service in city hotels and come up with strategies like offers to increase the booking in resort hotels.
# 2. About 26.2% of bookings get cancelled, thus stack holders must increase the deposit amount so that the number of cancellation go down and they make more profit.
# 3. Agent no 9 , 240 and 0 must be rewarded by stack holders for such outstanding performance thus increasing the competition among agents.
# 4. Sales team must be stressed more to perform in Summer season as it is the preferred season for hotel business. Also in off season sales techniques must be changed as it is more difficult to get customers in off seasons.
# 5. Room types A, D and E must be increased in hotels as they are mostly reserved and assigned.
# 6. Only 4.2% of guests return to the same hotel, thus guests staying can be given coupons or offers so that they come back to the same hotel again.
# 7. TA/TO, Corporate booking and direct channels performance must be flourished to gain more bookings.
# 8. Portugese, British and French dishes must be added and guests of these nationality must be made to feel comfortable by targeting their likings.
# 9. Meal type BB must be kept in stock at all times and techniques to sell other meal types must be rejuvenated.
# 10. Very less children have been seen to be guests, so parks and gaming zones may be built to attract guests with children.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Thus we have understood the numbers in which the guests come and also the trends in their stay, meal and language. Stack holders can target such nuances to gain significant advantage in the hotel business. New offers and packages must be given to the customers to attact them. Continuous update of the dataset, frequest analysis and customer feedback is also preferred.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
